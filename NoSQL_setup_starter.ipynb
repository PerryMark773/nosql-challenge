')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b27fc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2804')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b280d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2810')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2815')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2819')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2821')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2823')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2825')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2827')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b282a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b282c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b282d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b282e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b282f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2832')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2833')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2835')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b283f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2845')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2849')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b284a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b284c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2851')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2853')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2854')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2855')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2856')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2857')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2859')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b285b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b285e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2865')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2866')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2868')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2869')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b286d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b286f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2874')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2875')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2879')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b287a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b287c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b287f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2882')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2886')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2888')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b288a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2897')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b289c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b289f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28a0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28a4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28a8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28a9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28ab')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28b5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28b6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28ba')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28bd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28be')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28c2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28c8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28c9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28cd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28ce')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28cf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28d2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28d3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28d4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28d5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28d7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28df')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28e2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28e3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28e6')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28e9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28ea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28f4')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28f7')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28f9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28fd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28fe')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b28ff')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2900')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2901')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2902')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2903')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2906')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b290a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b290b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b290d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b290e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2911')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2912')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2915')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2917')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2919')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b291d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2920')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2921')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2923')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2924')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2925')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2926')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b292b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b292d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2937')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2938')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2939')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2944')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2945')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2947')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b294f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2951')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2952')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b295b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2978')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2984')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2989')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b298a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b298e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b298f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2990')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2993')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2996')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2997')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2998')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2999')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b299b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29aa')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29b0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29bb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29bd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29c0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29c3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29cf')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29d3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29d5')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29da')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29db')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29dc')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29de')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29e0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29ea')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29f9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b29fe')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a07')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a09')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a0e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a12')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a1a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a1b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a1f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a23')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a26')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a27')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a2d')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a35')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a38')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a3a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a3b')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a3f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a40')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a41')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a44')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a45')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a47')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a48')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a49')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a4a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a4f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a50')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a51')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a53')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a54')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a56')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a57')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a59')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a5a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a5c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a60')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a62')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a68')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a69')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a6a')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a6c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a70')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a76')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a78')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a7c')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a89')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a8e')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a8f')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a90')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a95')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2a96')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2aa2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2aab')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2ab2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2abb')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2ac2')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2ac8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2acd')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2ad0')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2ad3')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2ad8')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2ad9')},
#  {'BusinessTypeID': 1, '_id': ObjectId('649b384f7568ea57279b2ae6')},
#  {'BusinessTypeID': '', '_id': ObjectId('649b3b6287e0b2f1d1c6175d')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({"BusinessName": "Penang Flavours"}, {"$set": {"BusinessTypeID": 1}})

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName": "Penang Flavours"}

# Retrieve the updated restaurant document
penang_flavours = establishments.find_one(query)

# Print the updated restaurant document
pprint(penang_flavours)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('649b3b6287e0b2f1d1c6175d'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query ={'LocalAuthorityName': 'Dover'}
result = establishments.count_documents(query)
print(f'Curently {result} documents have "Dover" listed as the Local Authority Name')
# Out:
# Cuurently 994 documents have "Dover" listed as the Local Authority Name

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
query ={'LocalAuthorityName': 'Dover'}
result = establishments.count_documents(query)
print(f'Curently {result} documents have "Dover" listed as the Local Authority Name')
# Out:
# Curently 0 documents have "Dover" listed as the Local Authority Name

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('649b384e7568ea57279a926e'),
#  'geocode': {'latitude': '51.086058', 'longitude': '1.196408'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %%
# Define the update operation to change the data type
update = [
    {"$set": {"geocode.longitude": {"$toDouble": "$geocode.longitude"}}},
    {"$set": {"geocode.latitude": {"$toDouble": "$geocode.latitude"}}}
]

# Update the documents in the collection
establishments.update_many({}, [{'$set':{"geocode.longitude": {"$toDouble": "$geocode.longitude"},
                                        "geocode.latitude": {"$toDouble": "$geocode.latitude"}}
}])

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set':{"geocode.longitude": {"$toDouble": "$geocode.longitude"},
                                        "geocode.latitude": {"$toDouble": "$geocode.latitude"}}
}])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set': {'RatingValue': {'$toInt': '$RatingValue'}}}])

# %%
# Check that the coordinates and rating value are now numbers
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('649b384e7568ea57279a926e'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %%
# Close the MongoDB connection
mongo.close()
